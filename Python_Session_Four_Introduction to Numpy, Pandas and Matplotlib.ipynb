# %% [markdown]
# # **Session 4: Introduction to NumPy, Pandas, and Matplotlib**
#
# ## **📌 Learning Objectives:**
# By the end of this session, you will:
# - Understand **NumPy** and how it handles arrays and numerical computations.
# - Learn about **Pandas** and how to work with structured data using **DataFrames**.
# - Explore **Matplotlib** and create basic plots and visualizations.
#
# 🚀 **Let's get started!**

# %% [markdown]
# ## **1️⃣ Introduction to NumPy**
# ### **🔹 What is NumPy?**
# **NumPy** is a powerful Python library for numerical computing. It provides support for multi-dimensional arrays and matrices, and comes with a variety of mathematical functions to operate on these arrays.
#
# **Key Features of NumPy:**
# - Efficient storage and manipulation of large arrays.
# - Element-wise operations (addition, subtraction, etc.) on arrays.
# - Linear algebra operations.
# - Random number generation and statistics functions.

# %%
import numpy as np

# Example of creating a 1D NumPy array and performing element-wise operation
arr = np.array([1, 2, 3, 4, 5])
print(f"1D Array: {arr}")

# Element-wise operation (square of each element)
arr_squared = arr ** 2
print(f"Squared Array: {arr_squared}")
# Out:
# 1D Array: [1 2 3 4 5]
# Squared Array: [ 1  4  9 16 25]

# %% [markdown]
# ### **🔹 Example of 2D NumPy Array**
# You can also create 2D arrays (matrices) and perform operations on them.

# %%
# Creating a 2D NumPy array (Matrix)
matrix = np.array([[1, 2], [3, 4], [5, 6]])
print(f"2D Matrix: 
{matrix}")

# Matrix multiplication (dot product)
matrix_mult = np.dot(matrix, matrix.T)
print(f"Matrix Multiplied by its Transpose: 
{matrix_mult}")

# %% [markdown]
# ## **2️⃣ Introduction to Pandas**
# ### **🔹 What is Pandas?**
# **Pandas** is a data manipulation and analysis library, specifically designed for working with tabular data (like spreadsheets or SQL databases). It provides powerful, flexible **DataFrame** and **Series** objects for working with structured data.
#
# **Key Features of Pandas:**
# - Handling and manipulation of structured data (tabular).
# - Handling missing data.
# - Data cleaning and transformation.
# - Grouping, sorting, and filtering.

# %% [markdown]
# ### **🔹 Creating a Pandas DataFrame**
# Now, let's create a DataFrame using data from NumPy arrays. Pandas allows us to easily structure data in tabular form.

# %%
import pandas as pd

# Creating a DataFrame from NumPy arrays
data = {
    'MathScore': np.array([88, 92, 79, 85, 94]),
    'ReadingScore': np.array([89, 96, 72, 85, 97]),
    'WritingScore': np.array([91, 87, 78, 84, 93])
}

df = pd.DataFrame(data)
df
# Out:
#    MathScore  ReadingScore  WritingScore
# 0         88            89            91
# 1         92            96            87
# 2         79            72            78
# 3         85            85            84
# 4         94            97            93

# %% [markdown]
# ### **🔹 Example of Basic Operations on DataFrame**
# You can perform various operations like filtering, sorting, and accessing data from DataFrames.

# %%
list[0]
df['columnname']

# %%
print(df['MathScore'])
# Out:
# 0    88
# 1    92
# 2    79
# 3    85
# 4    94
# Name: MathScore, dtype: int32

# %%
# Accessing a specific column
# print(f"Names:
# {df['MathScore']}")

# Filtering rows where MathScore > 85
filtered_df = df[df['MathScore'] > 85]
print(filtered_df)
# Out:
#    MathScore  ReadingScore  WritingScore
# 0         88            89            91
# 1         92            96            87
# 4         94            97            93

# %% [markdown]
# ## **3️⃣ Introduction to Matplotlib**
# ### **🔹 What is Matplotlib?**
# **Matplotlib** is a plotting library for Python, providing functions to create a wide variety of visualizations like line plots, bar charts, histograms, and more.
#
# **Key Features of Matplotlib:**
# - Creating various types of plots (line, bar, scatter, etc.).
# - Customization (titles, labels, legends, etc.).
# - Integration with other libraries like Pandas for visualization.

# %%
import matplotlib.pyplot as plt

# Data for plotting
x = df['MathScore']
y = df['ReadingScore']

# Plotting a scatter plot to visualize Math vs. Reading Scores
plt.scatter(x, y)
plt.title('Math vs. Reading Scores')
plt.xlabel('Math Score')
plt.ylabel('Reading Score')
plt.show()

# %% [markdown]
# ### **🔹 Creating a Bar Plot**
# A bar plot is useful for comparing quantities across different categories.

# %%
# Data for bar plot
x = ['A', 'B', 'C', 'D']
y = [10, 15, 7, 20]

# Plotting the bar graph
plt.bar(x, y)
plt.title('Bar Plot Example')
plt.xlabel('Categories')
plt.ylabel('Values')
plt.show()

# %% [markdown]
# ### **🔹 Creating a Pie Chart**
# Pie charts are useful for showing proportions of a whole.

# %%
# Data for pie chart
labels = ['Math', 'Reading', 'Writing']
sizes = [35, 35, 30]

# Plotting the pie chart
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
plt.title('Performance Distribution by Subject')
plt.show()

# %% [markdown]
# ### **🔹 Creating a Histogram**
# Histograms are used for visualizing the distribution of numerical data.

# %%
# Data for histogram
scores = df['MathScore']

# Plotting the histogram
plt.hist(scores, bins=5, edgecolor='black')
plt.title('Distribution of Math Scores')
plt.xlabel('Math Score')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## **4️⃣ Combining NumPy, Pandas, and Matplotlib**
# In real-world applications, we often combine **NumPy** for numerical operations, **Pandas** for data manipulation, and **Matplotlib** for visualization. Below is an example that demonstrates all three libraries.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Creating a DataFrame with Pandas
data = {
    'Year': [2010, 2011, 2012, 2013, 2014],
    'Revenue': [100, 150, 200, 250, 300]
}

df = pd.DataFrame(data)

# Perform a simple NumPy operation (growth rate calculation)
df['Growth Rate'] = np.diff(df['Revenue'], prepend=df['Revenue'][0]) / df['Revenue'][0] * 100

# Plotting the data with Matplotlib
plt.plot(df['Year'], df['Revenue'], label='Revenue')
plt.plot(df['Year'], df['Growth Rate'], label='Growth Rate')

plt.title('Revenue and Growth Rate Over Years')
plt.xlabel('Year')
plt.ylabel('Value')
plt.legend()
plt.show()

# %% [markdown]
# # Creating a DataFrame from a csv file

# %%
# reading the csv file
df_exams = pd.read_csv('StudentsPerformance.csv')

# %%
df_exams.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# ...

# %%
# show first 5 rows in a dataframe
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# # Displaying a Dataframe

# %%
# show first 5 rows in a dataframe
df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
# show last 5 rows in a dataframe
df_exams.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
# show last n rows in a dataframe
df_exams.tail(10)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 990    male        group E                 high school  free/reduced
# 991  female        group B            some high school      standard
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 994    male        group A                 high school      standard
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 990               completed          86             81             75
# ...

# %%
#getting access to the shape attribute
df_exams.shape
# Out:
# (1000, 8)

# %%
# display n rows
pd.set_option('display.max_rows', 1000)
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 10     male        group C          associate's degree      standard
# 11     male        group D          associate's degree      standard
# 12   female        group B                 high school      standard
# ...

# %% [markdown]
# # Basic Attributes, Methods and Functions

# %% [markdown]
# ## Attributes

# %%
# getting access to the shape attribute
df_exams.shape
# Out:
# (1000, 8)

# %%
# getting access to the index attribute
df_exams.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
# getting access to the column attribute
df_exams.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
# data types of each column
df_exams.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %% [markdown]
# ## Methods

# %%
# showing the first 5 columns
df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
# showing the info of the dataframe
df_exams.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
# describing basic statistics of the dataframe
df_exams.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# ## Functions

# %%
# obtaining the length of the dataframe (number of rows)
len(df_exams)

# %%
# obtaining the highest index of the dataframe
max(df_exams.index)

# %%
# obtaining the lowest index of the dataframe
min(df_exams.index)

# %%
# obtaining the data type
type(df_exams)

# %%
# rounding the values of the dataset
round(df_exams, 2)

# %% [markdown]
# ## Selecting One Column from a Dataframe

# %% [markdown]
# ### Syntax 1

# %%
# select a column with [] (preferred way to select a column)
df_exams['gender']

# %%
# check out the data type of a column
type(df_exams['gender'])

# %%
# series: attributes and methods
df_exams['gender'].index
df_exams['gender'].head()

# %% [markdown]
# ### Syntax 2

# %%
# select a column with .
df_exams.gender

# %%
# select a column with . (pitfalls)
df_exams.math score

# %%
# select the same column using []
df_exams["math score"]

# %% [markdown]
# ## Selecting two or more columns

# %%
# select 2 columns using [[]]
df_exams[['gender', 'math score']]

# %%
# check out the data type of the selection
type(df_exams[['gender', 'math score']])

# %%
# select 2 or more columns using [[]]
df_exams[['gender', 'math score', 'reading score', 'writing score']]

# %% [markdown]
# ## Adding a new column

# %% [markdown]
# ### Adding a new column with a scalar value

# %%
# adding new column to dataframe
df_exams['language score'] = 70
df_exams

# %% [markdown]
# ### Adding a new column with an array

# %%
The dataframe has 1000 rows, so we need to create an array with 1000 elements

# %%
# import numpy
import numpy as np

# %%
# create an array of 1000 elements
language_score = np.arange(0, 1000)

# %%
# length of the array
len(language_score)

# %%
# adding a new column to dataframe with an array
df_exams['language score'] = language_score
df_exams

# %%
# create random integer numbers between 1 and 100
int_language_score = np.random.randint(1, 100, size=1000)

# %%
# min value inclusive and high value exclusive
print(min(int_language_score))
print(max(int_language_score))

# %%
# adding a new column to dataframe with an array
df_exams['language score'] = int_language_score
df_exams

# %%
# create random float numbers between 1 and 100
np.random.uniform(1, 100, size=1000)

# %% [markdown]
# ## Math Operations

# %% [markdown]
# ### Operations in columns

# %%
# select a column and calculate total sum
df_exams['math score'].sum()

# %%
# count, mean, std, max, and min
df_exams['math score'].count()
df_exams['math score'].mean()
df_exams['math score'].std()
df_exams['math score'].max()
df_exams['math score'].min()

# %%
# easier calculation with .describe()
df_exams.describe()

# %% [markdown]
# ### Operations in rows

# %%
# calculating the sum in a row
df_exams['math score'] + df_exams['reading score'] + df_exams['writing score']

# %%
# calculating the average score and assigning the result to a new column
df_exams['average'] = (df_exams['math score'] + df_exams['reading score'] + df_exams['writing score'])/3

# %%
# showing the dataframe
df_exams

# %% [markdown]
# ## Value Counts

# %%
# counting gender elements

# len function
len(df_exams['gender'])
# .count() method
df_exams['gender'].count()

# %%
# counting gender elements by category
df_exams['gender'].value_counts()

# %%
# return the relative frequency (divide all values by the sum of values)
df_exams['gender'].value_counts(normalize=True)

# %%
# counting "parental level of education" elements by category
df_exams['parental level of education'].value_counts()

# %%
# return the relative frequency and round to 2 decimals
df_exams['parental level of education'].value_counts(normalize=True).round(2)

# %% [markdown]
# ## Sort a dataframe

# %%
# sort by one column
df_exams.sort_values('math score')

# %%
# sort descending by one column
df_exams.sort_values('math score', ascending=False)

# %%
# sort descending by multiple columns
df_exams.sort_values(['math score', 'reading score'], ascending=False)

# %%
# sort descending by multiple columns and update dataframe
df_exams.sort_values(['math score', 'reading score'], ascending=False, inplace=True)

# %%
# sort descending with a key function
df_exams.sort_values(['race/ethnicity'], ascending=True, key=lambda a:a.str.lower())

# %% [markdown]
# ## Visualizations

# %%
df = df_exams

# %%
# Create new columns based on the dataset
df['total_score'] = df['math score'] + df['reading score'] + df['writing score']
df['average_score'] = df['total_score'] / 3
df['pass_fail'] = df['total_score'].apply(lambda x: 1 if x >= 180 else 0)

# Show the new dataset with the added columns
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total_score  average_score  pass_fail
# 0          218      72.666667          1
# 1          247      82.333333          1
# ...

# %%
df.shape
# Out:
# (1000, 11)

# %%
# Bar plot for the distribution of total scores
plt.figure(figsize=(10, 6))
plt.bar(df.index, df['total_score'], color='skyblue')
plt.title('Distribution of Total Scores')
plt.xlabel('Student Index')
plt.ylabel('Total Score')
plt.show()

# %%
# Scatter plot comparing Math and Reading scores
plt.figure(figsize=(10, 6))
plt.scatter(df['math score'], df['reading score'], color='orange')
plt.title('Math vs. Reading Scores')
plt.xlabel('Math Score')
plt.ylabel('Reading Score')
plt.show()

# %%
# Box plot showing the distribution of scores for each subject
plt.figure(figsize=(10, 6))
plt.boxplot([df['math score'], df['reading score'], df['writing score']], labels=['Math', 'Reading', 'Writing'])
plt.title('Score Distribution by Subject')
plt.ylabel('Score')
plt.show()

# %%
# Histogram for Math Scores distribution
plt.figure(figsize=(10, 6))
plt.hist(df['math score'], bins=10, color='lightgreen', edgecolor='black')
plt.title('Distribution of Math Scores')
plt.xlabel('Math Score')
plt.ylabel('Frequency')
plt.show()

# %%
# Pie chart for Pass/Fail distribution
pass_fail_counts = df['pass_fail'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(pass_fail_counts, labels=['Fail', 'Pass'], autopct='%1.1f%%', startangle=90, colors=['red', 'green'])
plt.title('Pass/Fail Distribution')
plt.show()

# %%
# Stacked bar chart for subject scores by Gender
gender_grouped = df.groupby('gender')[['math score', 'reading score', 'writing score']].sum()
gender_grouped.plot(kind='bar', stacked=True, figsize=(10, 6), color=['skyblue', 'orange', 'green'])
plt.title('Total Scores by Gender')
plt.xlabel('Gender')
plt.ylabel('Total Score')
plt.show()

# %%
import seaborn as sns

# Compute the correlation matrix for Math, Reading, and Writing scores
corr_matrix = df[['math score', 'reading score', 'writing score']].corr()

# Plot the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix of Scores')
plt.show()

# %%
# Line chart for average scores over the student index
plt.figure(figsize=(10, 6))
plt.plot(df.index, df['average_score'], color='purple', marker='o', linestyle='dashed')
plt.title('Average Scores of Students')
plt.xlabel('Student Index')
plt.ylabel('Average Score')
plt.show()

# %% [markdown]
# ## **📌 Summary of Session 4**
# ✔ **NumPy**: Efficient numerical operations with arrays.
#
# ✔ **Pandas**: Data manipulation and analysis with DataFrames.
#
# ✔ **Matplotlib**: Visualization of data using plots and charts.
#
#
# 🚀 **Next Up: Real-World Data Projects!**
